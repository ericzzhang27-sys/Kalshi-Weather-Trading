# %% [markdown]
# # Inspect NDFD Download
#
# Use this notebook after running the NDFD CLI to inspect the manifest, point forecast output, and daily feature output.

# %%
from pathlib import Path
import pandas as pd

manifest_path = Path('../outputs/data/ndfd_download_manifest.csv')
point_path = Path('../outputs/data/ndfd_knyc_point_forecasts.csv')
daily_path = Path('../outputs/data/ndfd_knyc_daily_features.csv')

for path in [manifest_path, point_path, daily_path]:
    print(path, path.exists())

# %%
manifest = pd.read_csv(manifest_path) if manifest_path.exists() else pd.DataFrame()
manifest.head(20)

# %%
point = pd.read_csv(point_path) if point_path.exists() else pd.DataFrame()
point.head(20)

# %%
daily = pd.read_csv(daily_path) if daily_path.exists() else pd.DataFrame()
daily.head(20)
